# %%
# dataframe
import pandas as pd

# basic math and stats formulas and plots
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# train-test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# model metrics validation
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from keras.metrics import Recall
from sklearn.metrics import recall_score

# neural network
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Dataset transformation
# First thing is importing the dataset and select only the columns that we will use for the neural network

# %%
# Importing the dataset
df1 = pd.read_csv('torino.csv')
columns = ['Julian', 'pressure', 'wind_direction', 'wind_speed', 'past_weather1', 'past_weather2', 'drybulb', 'dewpoint', 'fog']
df = df1[columns]

# %%
df.isna().sum()
# Out:
# Julian                0
# pressure              0
# wind_direction        0
# wind_speed            0
# past_weather1         0
# past_weather2         0
# drybulb           72798
# dewpoint          72797
# fog                   0
# dtype: int64

# %% [markdown]
# Now we want to train the neural network with the data in which drybulb and dewpoint have been measured. So we drop all the rows with NaN values being that the only NaN are in these two columns. The next step is scaling all the numerical variables and transform the categorical variables in multiple binary variables.

# %%
df2 = df.copy()
df2 = df2.dropna()
df2 = df2.reset_index(drop = 1)

# Transforming the categorical variables
categorical = ['past_weather1', 'past_weather2']
df_cat = df2[categorical].copy()
df_cat = pd.get_dummies(df_cat, columns = df_cat.columns.values)

# Scaling the numerical variables
numerical = ['Julian', 'pressure', 'wind_direction', 'wind_speed', 'drybulb', 'dewpoint']
df_num = df2[numerical].copy()
scaler = StandardScaler()  
df_num1 = scaler.fit_transform(df_num)
df_num1 = pd.DataFrame(df_num1, columns = df_num.columns.values)

# Merging the categorical and numerical variables
dfNN = pd.concat([df_cat, df_num1], axis = 1)
dfNN['fog'] = df2['fog']
print(dfNN.shape)
dfNN.isna().sum()
# Out:
# (44450, 27)
# past_weather1_0    0
# past_weather1_1    0
# past_weather1_2    0
# past_weather1_3    0
# past_weather1_4    0
# past_weather1_5    0
# past_weather1_6    0
# past_weather1_7    0
# past_weather1_8    0
# past_weather1_9    0
# past_weather2_0    0
# past_weather2_1    0
# past_weather2_2    0
# past_weather2_3    0
# past_weather2_4    0
# past_weather2_5    0
# past_weather2_6    0
# past_weather2_7    0
# past_weather2_8    0
# past_weather2_9    0
# Julian             0
# pressure           0
# wind_direction     0
# wind_speed         0
# drybulb            0
# dewpoint           0
# fog                0
# dtype: int64

# %% [markdown]
# # Splitting
# Now we can start to split the dataset in predictors and target and then in training and testing values (the test set size will be 20% of the dataset while the validation set size will be the 25%)

# %%
X = dfNN.drop('fog', axis=1)  
y = dfNN['fog']

# Split dataset into training set, test set and validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

_, X_val, _, y_val = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)

X_train, X_test, X_val, y_train, y_test, y_val = X_train.values, X_test.values, X_val.values, y_train.values, y_test.values, y_val.values

# Visualization of datasets shapes and fog percentages
fog_pct = np.sum(y) * 100 / len(y)

print(f'Training shape: {X_train.shape, y_train.shape}')
print(f'Validation shape: {X_val.shape, y_val.shape}')
print(f'Testing shape: {X_test.shape, y_test.shape}')
print(f'Fog percentage: {np.round(fog_pct, 3)}')


# condition to skip tuning
condition = 1
# Out:
# Training shape: ((35560, 26), (35560,))
# Validation shape: ((11113, 26), (11113,))
# Testing shape: ((8890, 26), (8890,))
# Fog percentage: 12.873

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# For the training of the neural network we start with a hyperparameter tuning. The grid is:
#
# - number of neurons: 16, 32, 64
# - activation function (of the hidden layer): relu, sigmoid, tanh
# - optimizer: SGD, Adam, RMSprop, Adadelta
# - batch_size: 8, 16, 32
#
# Being a binary classification the activation function of the last layer is set to sigmoid and the loss function is the binary crossentropy.
# The metrics considered apart from the loss are accuracy and recall. We added the recall because the dataset is imbalanced so the accuracy is "falsely" high. So if we use the recall we know how many fog cases are predicted respect to the true number of fog cases.
# At this neural network we added a callback. Basically if the recall on the validation set doesn't increase for 25 epochs the neural network is forced to stop.
# For every set of parameters is stored the accuracy and the recall of the predictions on the test set.

# %%
# Fine tuning
activationL = ['relu', 'sigmoid', 'tanh']
results = []
counter = 0

# for neurons in [16, 32, 64]:
#     for activation in activationL:
#         for opt in ['SGD', 'Adam', 'RMSprop', 'Adadelta']:
#             for batch_size in [8, 16, 32]:

#                 np.random.seed(1)
#                 print('*' * 50)
#                 print('Parameters:')
#                 print(f'No. neurons: {neurons}')
#                 print(f'Activation: {activation}')
#                 print(f'Optimizer: {opt}')
#                 print(f'Batch size: {batch_size}')
                
#                 # Creation of the model
#                 model = Sequential()
#                 model.add(Dense(neurons, input_dim = X_train.shape[1], activation = activation))
#                 model.add(Dense(1, activation = 'sigmoid'))

#                 # Compile the model with custom recall metric
#                 model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy', tf.keras.metrics.Recall()])

#                 # Condition of early stopping by monitoring the recall on the validation set
#                 if counter == 0:
#                     es = EarlyStopping(monitor='val_recall', 
#                                     mode='max',
#                                     patience=25,
#                                     restore_best_weights=True)
#                 else:
#                     es = EarlyStopping(monitor=f'val_recall_{counter}', 
#                                     mode='max',
#                                     patience=25,
#                                     restore_best_weights=True)
                    
#                 counter += 1

#                 # LSTM fitting
#                 model.fit(X_train, y_train, validation_data=(X_val, y_val), verbose = 1, epochs = 100, batch_size = batch_size, callbacks=[es])

#                 # Predictions of the model on the test set
#                 preds = np.round(model.predict(X_test), 0)
                
#                 # Storing the metrics (accuracy, recall) on the test set in a list
#                 score1 = recall_score(y_test, preds, pos_label=1)
#                 score2 = accuracy_score(y_test, preds)
#                 params = [neurons, activation, batch_size, opt, score1, score2]
#                 results.append(params)

# condition = 0

# %% [markdown]
# To select the parameters with best performances we take the parameters that bring to the best accuracy but also the parameters that bring to the best accuracy + recall

# %%
if condition==0:
    results_df=pd.DataFrame(results,columns=['neurons', 'activation', 'batch_size', 'opt', 'hops', 'score1', 'score2'])
    results_df.to_csv('MLP_torinoTuning.csv',index=False)
else:
    results_df=pd.read_csv('MLP_torinoTuning.csv')
    
    results = list(results_df.values)

# %% [markdown]
# # Best model selection

# %%
mix = [x[4] + x[5] for x in results]
best_mix_ind = mix.index(np.max(mix))
best_mix = results[best_mix_ind]

accuracies = [x[5] for x in results]
best_acc_ind = accuracies.index(np.max(accuracies))
best_acc = results[best_acc_ind]


print(f'Best accuracy + recall: {best_mix}')
print(f'Best accuracy: {best_acc}')
# Out:
# Best accuracy + recall: [64 'tanh' 16 'Adam' 0.958041958041958 0.9761529808773904]
# Best accuracy: [32 'relu' 32 'Adam' 0.9501748251748252 0.9770528683914512]

# %% [markdown]
# We run again the neural network with the best parameters to plot the results.

# %%
np.random.seed(1)

if condition == 1:
    metric = 'val_recall'
else:
    metric = f'val_recall_{counter}'

# Best parameters
neurons, activation, batch_size, opt = best_mix[0], best_mix[1], best_mix[2], best_mix[3]

# Creation of the model
model = Sequential()
model.add(Dense(neurons, input_dim = X_train.shape[1], activation = activation))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy', tf.keras.metrics.Recall()])

# Condition of early stopping by monitoring the recall on the validation set
es = EarlyStopping(monitor=metric, 
                mode='max',
                patience=25,
                restore_best_weights=True)

# Fitting the model and storing all metrics in the variable history
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), verbose = 1, epochs = 100, batch_size = batch_size, callbacks=[es])
# Out:
# Epoch 1/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0897 - accuracy: 0.9684 - recall: 0.8777 - val_loss: 0.0699 - val_accuracy: 0.9717 - val_recall: 0.8959
# Epoch 2/100
# 2223/2223 [==============================] - 2s 987us/step - loss: 0.0700 - accuracy: 0.9736 - recall: 0.8912 - val_loss: 0.0678 - val_accuracy: 0.9735 - val_recall: 0.8924
# Epoch 3/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0689 - accuracy: 0.9738 - recall: 0.8960 - val_loss: 0.0673 - val_accuracy: 0.9737 - val_recall: 0.8840
# Epoch 4/100
# 2223/2223 [==============================] - 2s 974us/step - loss: 0.0681 - accuracy: 0.9741 - recall: 0.8965 - val_loss: 0.0672 - val_accuracy: 0.9730 - val_recall: 0.8777
# Epoch 5/100
# 2223/2223 [==============================] - 2s 994us/step - loss: 0.0673 - accuracy: 0.9744 - recall: 0.8989 - val_loss: 0.0661 - val_accuracy: 0.9731 - val_recall: 0.8959
# Epoch 6/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0665 - accuracy: 0.9745 - recall: 0.9024 - val_loss: 0.0658 - val_accuracy: 0.9738 - val_recall: 0.8826
# Epoch 7/100
# 2223/2223 [==============================] - 2s 983us/step - loss: 0.0660 - accuracy: 0.9747 - recall: 0.9010 - val_loss: 0.0642 - val_accuracy: 0.9758 - val_recall: 0.9147
# Epoch 8/100
# 2223/2223 [==============================] - 2s 984us/step - loss: 0.0654 - accuracy: 0.9747 - recall: 0.9017 - val_loss: 0.0641 - val_accuracy: 0.9755 - val_recall: 0.9168
# Epoch 9/100
# 2223/2223 [==============================] - 2s 970us/step - loss: 0.0648 - accuracy: 0.9750 - recall: 0.9069 - val_loss: 0.0628 - val_accuracy: 0.9753 - val_recall: 0.9022
# Epoch 10/100
# 2223/2223 [==============================] - 2s 982us/step - loss: 0.0644 - accuracy: 0.9754 - recall: 0.9102 - val_loss: 0.0633 - val_accuracy: 0.9762 - val_recall: 0.9217
# Epoch 11/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0637 - accuracy: 0.9758 - recall: 0.9085 - val_loss: 0.0631 - val_accuracy: 0.9770 - val_recall: 0.9196
# Epoch 12/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0636 - accuracy: 0.9759 - recall: 0.9142 - val_loss: 0.0640 - val_accuracy: 0.9759 - val_recall: 0.9308
# Epoch 13/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0629 - accuracy: 0.9769 - recall: 0.9176 - val_loss: 0.0618 - val_accuracy: 0.9764 - val_recall: 0.9140
# Epoch 14/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0626 - accuracy: 0.9765 - recall: 0.9163 - val_loss: 0.0614 - val_accuracy: 0.9769 - val_recall: 0.9238
# Epoch 15/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0624 - accuracy: 0.9767 - recall: 0.9181 - val_loss: 0.0609 - val_accuracy: 0.9780 - val_recall: 0.9448
# Epoch 16/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0622 - accuracy: 0.9769 - recall: 0.9168 - val_loss: 0.0632 - val_accuracy: 0.9754 - val_recall: 0.9525
# Epoch 17/100
# 2223/2223 [==============================] - 2s 971us/step - loss: 0.0618 - accuracy: 0.9771 - recall: 0.9201 - val_loss: 0.0607 - val_accuracy: 0.9763 - val_recall: 0.9329
# Epoch 18/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0614 - accuracy: 0.9774 - recall: 0.9216 - val_loss: 0.0605 - val_accuracy: 0.9772 - val_recall: 0.9126
# Epoch 19/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0614 - accuracy: 0.9771 - recall: 0.9233 - val_loss: 0.0592 - val_accuracy: 0.9782 - val_recall: 0.9371
# Epoch 20/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0612 - accuracy: 0.9778 - recall: 0.9231 - val_loss: 0.0601 - val_accuracy: 0.9780 - val_recall: 0.9182
# Epoch 21/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0609 - accuracy: 0.9779 - recall: 0.9255 - val_loss: 0.0597 - val_accuracy: 0.9776 - val_recall: 0.9245
# Epoch 22/100
# 2223/2223 [==============================] - 2s 962us/step - loss: 0.0605 - accuracy: 0.9776 - recall: 0.9246 - val_loss: 0.0601 - val_accuracy: 0.9765 - val_recall: 0.8924
# Epoch 23/100
# 2223/2223 [==============================] - 2s 1000us/step - loss: 0.0602 - accuracy: 0.9782 - recall: 0.9244 - val_loss: 0.0600 - val_accuracy: 0.9780 - val_recall: 0.9322
# Epoch 24/100
# 2223/2223 [==============================] - 2s 979us/step - loss: 0.0604 - accuracy: 0.9777 - recall: 0.9246 - val_loss: 0.0610 - val_accuracy: 0.9777 - val_recall: 0.9560
# Epoch 25/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0604 - accuracy: 0.9775 - recall: 0.9260 - val_loss: 0.0583 - val_accuracy: 0.9780 - val_recall: 0.9392
# Epoch 26/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0598 - accuracy: 0.9784 - recall: 0.9257 - val_loss: 0.0596 - val_accuracy: 0.9774 - val_recall: 0.9371
# Epoch 27/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0596 - accuracy: 0.9780 - recall: 0.9273 - val_loss: 0.0592 - val_accuracy: 0.9775 - val_recall: 0.8952
# Epoch 28/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0596 - accuracy: 0.9787 - recall: 0.9275 - val_loss: 0.0582 - val_accuracy: 0.9783 - val_recall: 0.9308
# Epoch 29/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0597 - accuracy: 0.9781 - recall: 0.9275 - val_loss: 0.0587 - val_accuracy: 0.9785 - val_recall: 0.9133
# Epoch 30/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0592 - accuracy: 0.9781 - recall: 0.9284 - val_loss: 0.0582 - val_accuracy: 0.9779 - val_recall: 0.9469
# Epoch 31/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0593 - accuracy: 0.9782 - recall: 0.9275 - val_loss: 0.0585 - val_accuracy: 0.9780 - val_recall: 0.9252
# Epoch 32/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0590 - accuracy: 0.9788 - recall: 0.9288 - val_loss: 0.0575 - val_accuracy: 0.9785 - val_recall: 0.9406
# Epoch 33/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0590 - accuracy: 0.9790 - recall: 0.9297 - val_loss: 0.0580 - val_accuracy: 0.9784 - val_recall: 0.9329
# Epoch 34/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0586 - accuracy: 0.9789 - recall: 0.9316 - val_loss: 0.0601 - val_accuracy: 0.9777 - val_recall: 0.9301
# Epoch 35/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0586 - accuracy: 0.9790 - recall: 0.9305 - val_loss: 0.0578 - val_accuracy: 0.9780 - val_recall: 0.9231
# Epoch 36/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0586 - accuracy: 0.9787 - recall: 0.9290 - val_loss: 0.0571 - val_accuracy: 0.9785 - val_recall: 0.9427
# Epoch 37/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0584 - accuracy: 0.9788 - recall: 0.9305 - val_loss: 0.0579 - val_accuracy: 0.9789 - val_recall: 0.9301
# Epoch 38/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0582 - accuracy: 0.9787 - recall: 0.9312 - val_loss: 0.0593 - val_accuracy: 0.9786 - val_recall: 0.9497
# Epoch 39/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0581 - accuracy: 0.9788 - recall: 0.9308 - val_loss: 0.0582 - val_accuracy: 0.9785 - val_recall: 0.9560
# Epoch 40/100
# 2223/2223 [==============================] - 2s 998us/step - loss: 0.0579 - accuracy: 0.9787 - recall: 0.9312 - val_loss: 0.0575 - val_accuracy: 0.9789 - val_recall: 0.9343
# Epoch 41/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0579 - accuracy: 0.9791 - recall: 0.9312 - val_loss: 0.0574 - val_accuracy: 0.9780 - val_recall: 0.9350
# Epoch 42/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0577 - accuracy: 0.9791 - recall: 0.9325 - val_loss: 0.0577 - val_accuracy: 0.9792 - val_recall: 0.9329
# Epoch 43/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0577 - accuracy: 0.9787 - recall: 0.9299 - val_loss: 0.0582 - val_accuracy: 0.9781 - val_recall: 0.9588
# Epoch 44/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0575 - accuracy: 0.9794 - recall: 0.9353 - val_loss: 0.0584 - val_accuracy: 0.9781 - val_recall: 0.9497
# Epoch 45/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0572 - accuracy: 0.9790 - recall: 0.9327 - val_loss: 0.0571 - val_accuracy: 0.9792 - val_recall: 0.9427
# Epoch 46/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0570 - accuracy: 0.9792 - recall: 0.9343 - val_loss: 0.0562 - val_accuracy: 0.9795 - val_recall: 0.9231
# Epoch 47/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0569 - accuracy: 0.9794 - recall: 0.9349 - val_loss: 0.0582 - val_accuracy: 0.9780 - val_recall: 0.9140
# Epoch 48/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0568 - accuracy: 0.9792 - recall: 0.9327 - val_loss: 0.0568 - val_accuracy: 0.9789 - val_recall: 0.9308
# Epoch 49/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0569 - accuracy: 0.9792 - recall: 0.9362 - val_loss: 0.0583 - val_accuracy: 0.9788 - val_recall: 0.9203
# Epoch 50/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0567 - accuracy: 0.9790 - recall: 0.9323 - val_loss: 0.0582 - val_accuracy: 0.9793 - val_recall: 0.9490
# Epoch 51/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0563 - accuracy: 0.9794 - recall: 0.9334 - val_loss: 0.0560 - val_accuracy: 0.9800 - val_recall: 0.9406
# Epoch 52/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0565 - accuracy: 0.9789 - recall: 0.9323 - val_loss: 0.0571 - val_accuracy: 0.9790 - val_recall: 0.9364
# Epoch 53/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0562 - accuracy: 0.9794 - recall: 0.9343 - val_loss: 0.0566 - val_accuracy: 0.9790 - val_recall: 0.9301
# Epoch 54/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0560 - accuracy: 0.9798 - recall: 0.9347 - val_loss: 0.0562 - val_accuracy: 0.9793 - val_recall: 0.9245
# Epoch 55/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0562 - accuracy: 0.9797 - recall: 0.9349 - val_loss: 0.0560 - val_accuracy: 0.9788 - val_recall: 0.9301
# Epoch 56/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0555 - accuracy: 0.9793 - recall: 0.9336 - val_loss: 0.0589 - val_accuracy: 0.9780 - val_recall: 0.9623
# Epoch 57/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0553 - accuracy: 0.9803 - recall: 0.9388 - val_loss: 0.0567 - val_accuracy: 0.9799 - val_recall: 0.9434
# Epoch 58/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0554 - accuracy: 0.9796 - recall: 0.9345 - val_loss: 0.0566 - val_accuracy: 0.9785 - val_recall: 0.9413
# Epoch 59/100
# 2223/2223 [==============================] - 3s 1ms/step - loss: 0.0556 - accuracy: 0.9795 - recall: 0.9325 - val_loss: 0.0566 - val_accuracy: 0.9788 - val_recall: 0.9511
# Epoch 60/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0550 - accuracy: 0.9799 - recall: 0.9382 - val_loss: 0.0564 - val_accuracy: 0.9794 - val_recall: 0.9406
# Epoch 61/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0552 - accuracy: 0.9799 - recall: 0.9386 - val_loss: 0.0560 - val_accuracy: 0.9793 - val_recall: 0.9273
# Epoch 62/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0551 - accuracy: 0.9797 - recall: 0.9356 - val_loss: 0.0567 - val_accuracy: 0.9789 - val_recall: 0.9553
# Epoch 63/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0549 - accuracy: 0.9801 - recall: 0.9369 - val_loss: 0.0560 - val_accuracy: 0.9789 - val_recall: 0.9371
# Epoch 64/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0548 - accuracy: 0.9798 - recall: 0.9373 - val_loss: 0.0560 - val_accuracy: 0.9792 - val_recall: 0.9315
# Epoch 65/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0549 - accuracy: 0.9799 - recall: 0.9356 - val_loss: 0.0550 - val_accuracy: 0.9800 - val_recall: 0.9448
# Epoch 66/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0545 - accuracy: 0.9802 - recall: 0.9375 - val_loss: 0.0559 - val_accuracy: 0.9792 - val_recall: 0.9469
# Epoch 67/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0546 - accuracy: 0.9800 - recall: 0.9377 - val_loss: 0.0550 - val_accuracy: 0.9791 - val_recall: 0.9455
# Epoch 68/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0543 - accuracy: 0.9801 - recall: 0.9373 - val_loss: 0.0554 - val_accuracy: 0.9798 - val_recall: 0.9301
# Epoch 69/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0541 - accuracy: 0.9799 - recall: 0.9364 - val_loss: 0.0553 - val_accuracy: 0.9798 - val_recall: 0.9245
# Epoch 70/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0541 - accuracy: 0.9805 - recall: 0.9397 - val_loss: 0.0547 - val_accuracy: 0.9796 - val_recall: 0.9280
# Epoch 71/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0539 - accuracy: 0.9804 - recall: 0.9362 - val_loss: 0.0553 - val_accuracy: 0.9793 - val_recall: 0.9462
# Epoch 72/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0538 - accuracy: 0.9805 - recall: 0.9393 - val_loss: 0.0559 - val_accuracy: 0.9802 - val_recall: 0.9511
# Epoch 73/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0538 - accuracy: 0.9805 - recall: 0.9373 - val_loss: 0.0552 - val_accuracy: 0.9791 - val_recall: 0.9476
# Epoch 74/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0538 - accuracy: 0.9805 - recall: 0.9397 - val_loss: 0.0543 - val_accuracy: 0.9796 - val_recall: 0.9350
# Epoch 75/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0535 - accuracy: 0.9801 - recall: 0.9358 - val_loss: 0.0545 - val_accuracy: 0.9799 - val_recall: 0.9553
# Epoch 76/100
# 2223/2223 [==============================] - 2s 1000us/step - loss: 0.0536 - accuracy: 0.9806 - recall: 0.9408 - val_loss: 0.0544 - val_accuracy: 0.9793 - val_recall: 0.9476
# Epoch 77/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0531 - accuracy: 0.9803 - recall: 0.9395 - val_loss: 0.0553 - val_accuracy: 0.9797 - val_recall: 0.9196
# Epoch 78/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0534 - accuracy: 0.9803 - recall: 0.9380 - val_loss: 0.0544 - val_accuracy: 0.9790 - val_recall: 0.9469
# Epoch 79/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0532 - accuracy: 0.9804 - recall: 0.9404 - val_loss: 0.0540 - val_accuracy: 0.9792 - val_recall: 0.9266
# Epoch 80/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0528 - accuracy: 0.9803 - recall: 0.9382 - val_loss: 0.0552 - val_accuracy: 0.9791 - val_recall: 0.9357
# Epoch 81/100
# 2223/2223 [==============================] - 2s 1ms/step - loss: 0.0531 - accuracy: 0.9804 - recall: 0.9362 - val_loss: 0.0542 - val_accuracy: 0.9789 - val_recall: 0.9336

# %% [markdown]
# # Performances

# %%
def predictions_results(X, y, model):
    preds = np.round(model.predict(X),0)

    # Measure recall and accuracy of the prediction
    score1 = recall_score(y, preds, pos_label=1)
    score2 = accuracy_score(y, preds)
    # Plotting the metrics, classification report and the confusion matrix

    print(f'Accuracy: {round(score2 * 100, 2)}')
    print(f'Recall: {round(score1 * 100, 2)}')

    cm = confusion_matrix(y, preds)
    disp = ConfusionMatrixDisplay(cm)
    print(classification_report(y, preds))
    disp.plot()
    plt.show()

# %% [markdown]
# ### Validation

# %%
predictions_results(X_val, y_val, model)
# Out:
# 348/348 [==============================] - 0s 654us/step
# Accuracy: 97.8
# Recall: 96.23
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      9682
#            1       0.88      0.96      0.92      1431
#
#     accuracy                           0.98     11113
#    macro avg       0.94      0.97      0.95     11113
# weighted avg       0.98      0.98      0.98     11113

# %% [markdown]
# ### Test

# %%
predictions_results(X_test, y_test, model)
# Out:
# 278/278 [==============================] - 0s 687us/step
# Accuracy: 97.68
# Recall: 95.19
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7746
#            1       0.88      0.95      0.91      1144
#
#     accuracy                           0.98      8890
#    macro avg       0.94      0.97      0.95      8890
# weighted avg       0.98      0.98      0.98      8890

# %% [markdown]
# ### Metrics

# %%
history_dict = history.history

# Loss
rec = history_dict[metric[4:]]
val_rec = history_dict[metric]

# Loss
loss = history_dict[f'loss']
val_loss = history_dict[f'val_loss']

# Accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(val_loss) + 1) 

# Plotting accuracy
plt.figure(figsize = (15,10))
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'orange', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting recall
plt.figure(figsize = (15,10))
plt.plot(epochs, rec, 'b', label='Training recall')
plt.plot(epochs, val_rec, 'orange', label='Validation recall')
plt.title('Training and validation recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.show()


# Plotting loss
plt.figure(figsize = (15,10))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
