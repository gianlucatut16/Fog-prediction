# %%
# dataframe
import pandas as pd

# basic math and stats formulas and plots
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# model metrics validation
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from keras.metrics import Recall
from sklearn.metrics import recall_score

# neural network
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers

# %% [markdown]
# # Dataset transformation

# %%
df = pd.read_csv('trapani.csv')
df = df.drop(['Unnamed: 0', 'cloud_cover', 'direction_bin'], axis = 1)
df['date']= pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# We check the dataset because the LSTM model is used with homogeneous time series. We plotted the date_diff variable vs the date. So a high peak tells us that there is a big gap in the time series at that date.

# %%
df = df[df['date'] >= pd.to_datetime("2013-09-01 00:00:00", format='%Y-%m-%d %H:%M:%S')]
plt.figure(figsize = (20,10))
sns.lineplot(data = df, x = 'date', y = 'date_diff')
plt.show()

# %% [markdown]
# We can see that there is an enormous gap in 2008 and that from 2016 the time series is quite messy. So we use as date range 2013-09-01 and 2016-01-01. (the first date was chosen also because it's the date where they started to measure drybulb and dewpoint)

# %%
df = df[df['date'] >= pd.to_datetime("2013-09-01 00:00:00", format='%Y-%m-%d %H:%M:%S')]
df = df[df['date'] <= pd.to_datetime("2016-01-01 00:00:00", format='%Y-%m-%d %H:%M:%S')]

# %%
fog_cases = df[df['fog'] == 1].shape[0]
fog_pct = fog_cases * 100/df.shape[0]

print(f'The fog cases are {fog_cases} ({round(fog_pct, 2)}%)')
# Out:
# The fog cases are 16 (0.08%)

# %%
# Resampling of time series to obtain hourly frequency
df2 = df.copy()
df2.index = df2['date']
df2 = df2.resample('1H').mean()
df2 = df2.drop(['Julian', 'date_diff', 'Month', 'Day', 'Hour', 'Year', 'present_weather', 'cloud_type', 'new_pres_weath'], axis = 1)

print(df2.shape)
df2.isna().sum()
# Out:
# (20449, 9)
# pressure          249
# wind_direction    249
# wind_speed        249
# visibility        249
# past_weather1     249
# past_weather2     249
# drybulb           253
# dewpoint          254
# fog               249
# dtype: int64

# %% [markdown]
# Getting the time series homogeneous has created some NaN that we can fill with an interpolation, obviously different for categorical and numerical variables

# %%
df1 = df2.copy()
df1 = df1.reset_index(drop = 1)

# Interpolation categorical
categorical = ['past_weather1', 'past_weather2']
df_cat = df1[categorical].copy()
df_cat = df_cat.interpolate(method = 'nearest')

# Interpolation numerical
numerical = ['pressure', 'wind_direction', 'wind_speed','drybulb', 'dewpoint', 'visibility']
df_num = df1[numerical].copy()
df_num = df_num.interpolate(method = 'linear')

# %% [markdown]
# Before scaling all the variables we create a variable to save the target

# %%
# Save the target fog in the variable y

y = []

for i in list(df_num['visibility']):
    if i <= 1000:
        y.append(1)
    else:
        y.append(0)

df_num = df_num.drop('visibility', axis = 1)

# %% [markdown]
# Now we can scale all the numerical variables and transform all the categorical variables to binary ones.

# %%
# Scaling numerical
scaler = StandardScaler()  
df_num1 = scaler.fit_transform(df_num)
df_num1 = pd.DataFrame(df_num1, columns = df_num.columns.values)

# Transforming categorical
df_cat1 = pd.get_dummies(df_cat, columns = df_cat.columns.values)

# Merging categorical and numerical
dfNN = pd.concat([df_cat1, df_num1], axis = 1)
dfNN['fog'] = y
dfNN.index = df2.index
print(dfNN.shape)
dfNN.isna().sum()
# Out:
# (20449, 24)
# past_weather1_0.0    0
# past_weather1_1.0    0
# past_weather1_2.0    0
# past_weather1_4.0    0
# past_weather1_5.0    0
# past_weather1_6.0    0
# past_weather1_7.0    0
# past_weather1_8.0    0
# past_weather1_9.0    0
# past_weather2_0.0    0
# past_weather2_1.0    0
# past_weather2_2.0    0
# past_weather2_3.0    0
# past_weather2_4.0    0
# past_weather2_5.0    0
# past_weather2_6.0    0
# past_weather2_7.0    0
# past_weather2_9.0    0
# pressure             0
# wind_direction       0
# wind_speed           0
# drybulb              0
# dewpoint             0
# fog                  0
# dtype: int64

# %% [markdown]
# # Splitting
# Now we can split the time series in training set and testing set with the splitting date at 2015-09-01. Obviously we build also a validation set using as splitting date 2015-06-01 (so we add 3 months to the test)

# %%
test_date = pd.to_datetime("2015-09-01 00:00:00", format='%Y-%m-%d %H:%M:%S')
val_date = pd.to_datetime("2015-06-01 00:00:00", format='%Y-%m-%d %H:%M:%S')

# Creation of training, validation, testing set
train = dfNN[dfNN.index <= test_date]
val =  dfNN[dfNN.index >= val_date]
test = dfNN[dfNN.index > test_date]


# Visualization of datasets shapes, fog cases and percentages
pct_train = train[train['fog'] == 1].shape[0] * 100 / train.shape[0] 
pct_val = val[val['fog'] == 1].shape[0] * 100 / val.shape[0] 
pct_test = test[test['fog'] == 1].shape[0] * 100 / test.shape[0] 

print(f'Training shape and fog percentage: {train.shape}, {round(pct_train,2)}%')
print(f'Validation shape and fog percentage: {val.shape}, {round(pct_val,2)}%')
print(f'Testing shape and fog percentage: {test.shape}, {round(pct_test,2)}%')
# Out:
# Training shape and fog percentage: (17521, 24), 0.05%
# Validation shape and fog percentage: (5137, 24), 0.18%
# Testing shape and fog percentage: (2928, 24), 0.27%

# %% [markdown]
# Here's a visualization of the split

# %%
plt.figure(figsize = (20,10))
plt.plot(train.index, train['pressure'], color = 'black', label = 'Training')
plt.plot(test.index, test['pressure'], color = 'red', label = 'Testing')
plt.legend()
plt.show()

# %%
# Splitting all the sets in predictors and target
n_features = 23

X_train = train.drop('fog', axis = 1).values
y_train = train['fog'].values

X_val = val.drop('fog', axis = 1).values
y_val = val['fog'].values

X_test = test.drop('fog', axis = 1).values
y_test = test['fog'].values

# condition to skip tuning

condition = 1

# %% [markdown]
# # Fine Tuning
# For the training of the neural network we start with a hyperparameter tuning. The grid is:
#
# - number of neurons: 16, 32, 64
# - activation function (of the hidden layer): relu, sigmoid, tanh
# - optimizer: SGD, Adam, RMSprop, Adadelta
# - batch_size: 8, 16, 32
# - hops: 10, 20, 30
#
# Being a binary classification the activation function of the last layer is set to sigmoid and the loss function is the binary crossentropy.
# The metrics considered apart from the loss are accuracy and recall. We added the recall because the dataset is extremely imbalanced so the accuracy is "falsely" high. So if we use the recall we know how many fog cases are predicted respect to the true number of fog cases.
# At this neural network we added a callback. Basically if the recall on the validation set doesn't increase for 25 epochs the neural network is forced to stop.
# For every set of parameters is stored the accuracy and the recall of the predictions on the test set.

# %%
activationL = ['relu', 'sigmoid', 'tanh']
results = []
counter = 0

# for neurons in [16, 32, 64]:
#     for activation in activationL:
#         for opt in ['SGD', 'Adam', 'RMSprop', 'Adadelta']:
#             for batch_size in [8, 16, 32]:
#                 for hops in [10, 20, 30]:

#                     np.random.seed(1)

#                     print('*' * 50)
#                     print('Parameters:')
#                     print(f'No. neurons: {neurons}')
#                     print(f'Activation: {activation}')
#                     print(f'Optimizer: {opt}')
#                     print(f'Batch size: {batch_size}')
#                     print(f'Hops: {hops}')


#                     # Creation of training set for LSTM
#                     X_train_lstm = []
#                     y_train_lstm = []

#                     for i in range(hops, len(y_train)):
#                         X_train_lstm.append(X_train[i-hops:i])
#                         y_train_lstm.append(y_train[i])

#                     X_train_lstm, y_train_lstm = np.array(X_train_lstm), np.array(y_train_lstm)
#                     X_train_def = np.reshape(X_train_lstm, (X_train_lstm.shape[0], X_train_lstm.shape[1], X_train_lstm.shape[2]))

#                     # Creation of validation set for LSTM
#                     X_val_lstm = []
#                     y_val_lstm = []

#                     for i in range(hops, len(y_val)):
#                         X_val_lstm.append(X_val[i-hops:i])
#                         y_val_lstm.append(y_val[i])

#                     X_val_lstm, y_val_lstm = np.array(X_val_lstm), np.array(y_val_lstm)
#                     X_val_def = np.reshape(X_val_lstm, (X_val_lstm.shape[0], X_val_lstm.shape[1], X_val_lstm.shape[2]))

#                     # Creation of testing set for LSTM
#                     X_test_lstm = []
#                     y_test_lstm = []

#                     for i in range(hops, len(y_test)):
#                         X_test_lstm.append(X_test[i-hops:i])
#                         y_test_lstm.append(y_test[i])

#                     X_test_lstm, y_test_lstm = np.array(X_test_lstm), np.array(y_test_lstm)
#                     X_test_def = np.reshape(X_test_lstm, (X_test_lstm.shape[0], X_test_lstm.shape[1], X_test_lstm.shape[2]))

#                     # Creation of the model
#                     model = Sequential()
#                     model.add(LSTM(units = neurons, input_shape = (hops, n_features), activation=activation))
#                     model.add(Dense(1, activation='sigmoid'))
#                     model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy', tf.keras.metrics.Recall()])
                    
#                     # Condition of early stopping by monitoring the recall on the validation set
#                     if counter == 0:
#                         es = EarlyStopping(monitor='val_recall', 
#                                                         mode='max',
#                                                         patience=25,
#                                                         restore_best_weights=True)
#                     else:
#                         es = EarlyStopping(monitor=f'val_recall_{counter}', 
#                                                         mode='max',
#                                                         patience=25,
#                                                         restore_best_weights=True)

#                     counter += 1

#                     # LSTM fitting
#                     history = model.fit(X_train_def, y_train_lstm, epochs = 100, batch_size=batch_size, verbose = 1, validation_data = (X_val_def, y_val_lstm), callbacks = [es])

#                     # Predictions of the model on the test set
#                     preds = np.round(model.predict(X_test_def),0)
                    
#                     # Storing the metrics (accuracy, recall) on the test set in a list
#                     try:
#                         score1 = recall_score(y_test_lstm, preds, pos_label=1)
#                         score2 = accuracy_score(y_test_lstm, preds)
#                     except:
#                         score1, score2 = 0,0
#                     params = [neurons, activation, batch_size, opt, hops, score1, score2]
#                     results.append(params)
# condition = 0

# %% [markdown]
# In this case, given the extreme imbalance of the dataset, we created a dataframe with parameters and results of the tuning (because the accuracy is very high and the best model is not the model with highest accuracy or accuracy + recall). Then we searched the best model in the dataframe.

# %%
if condition==0:
    results_df = pd.DataFrame(results, columns = ['neurons', 'activation', 'batch_size', 'optimizer', 'hops', 'recall', 'accuracy'])
    results_df.to_csv('LSTM_trapaniTuning.csv',index=False)
else:
    results_df=pd.read_csv('LSTM_trapaniTuning.csv')

# %% [markdown]
# # Best model selection

# %%
display(results_df[(results_df['accuracy'] > 0.5) & (results_df['recall'] > 0.5)])
# Out:
#      Unnamed: 0  neurons activation  batch_size optimizer  hops  recall  \
# 137         137       32       relu           8  Adadelta    30   0.750
# 141         141       32       relu          32  Adadelta    10   0.750
# 211         211       32       tanh          16  Adadelta    20   0.625
#
#      accuracy
# 137  0.795376
# 141  0.827964
# 211  0.881018

# %% [markdown]
# We run again the best model to plot the results.

# %%
np.random.seed(1)

if condition == 1:
    metric = 'val_recall'
else:
    metric = f'val_recall_{counter}'


neurons, activation, batch_size, opt, hops = 32, 'tanh', 16, 'Adadelta', 20

# Creation of training set for LSTM
X_train_lstm = []
y_train_lstm = []

for i in range(hops, len(y_train)):
    X_train_lstm.append(X_train[i-hops:i])
    y_train_lstm.append(y_train[i])

X_train_lstm, y_train_lstm = np.array(X_train_lstm), np.array(y_train_lstm)
X_train_def = np.reshape(X_train_lstm, (X_train_lstm.shape[0], X_train_lstm.shape[1], X_train_lstm.shape[2]))

# Creation of validation set for LSTM
X_val_lstm = []
y_val_lstm = []

for i in range(hops, len(y_val)):
    X_val_lstm.append(X_val[i-hops:i])
    y_val_lstm.append(y_val[i])

X_val_lstm, y_val_lstm = np.array(X_val_lstm), np.array(y_val_lstm)
X_val_def = np.reshape(X_val_lstm, (X_val_lstm.shape[0], X_val_lstm.shape[1], X_val_lstm.shape[2]))

# Creation of testing set for LSTM
X_test_lstm = []
y_test_lstm = []

for i in range(hops, len(y_test)):
    X_test_lstm.append(X_test[i-hops:i])
    y_test_lstm.append(y_test[i])

X_test_lstm, y_test_lstm = np.array(X_test_lstm), np.array(y_test_lstm)
X_test_def = np.reshape(X_test_lstm, (X_test_lstm.shape[0], X_test_lstm.shape[1], X_test_lstm.shape[2]))

# Creation of the model
model = Sequential()
model.add(LSTM(units = neurons, input_shape = (hops, n_features), activation=activation))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy', tf.keras.metrics.Recall()])

# Condition of early stopping by monitoring the recall on the validation set
es = EarlyStopping(monitor=metric, 
                                mode='max',
                                patience=25)

# Fitting the model and storing all metrics in the variable history
history = model.fit(X_train_def, y_train_lstm, epochs = 100, batch_size=batch_size, verbose = 1, validation_data = (X_val_def, y_val_lstm), callbacks = [es])
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 7s 5ms/step - loss: 0.6054 - accuracy: 0.7366 - recall: 0.8750 - val_loss: 0.5833 - val_accuracy: 0.8026 - val_recall: 0.5556
# Epoch 2/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.5634 - accuracy: 0.8455 - recall: 0.2500 - val_loss: 0.5375 - val_accuracy: 0.9492 - val_recall: 0.2222
# Epoch 3/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.5157 - accuracy: 0.9338 - recall: 0.2500 - val_loss: 0.4881 - val_accuracy: 0.9939 - val_recall: 0.1111
# Epoch 4/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.4648 - accuracy: 0.9798 - recall: 0.0000e+00 - val_loss: 0.4366 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 5/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.4114 - accuracy: 0.9952 - recall: 0.0000e+00 - val_loss: 0.3832 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 6/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.3562 - accuracy: 0.9981 - recall: 0.0000e+00 - val_loss: 0.3290 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 7/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.3005 - accuracy: 0.9991 - recall: 0.0000e+00 - val_loss: 0.2753 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 8/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.2465 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.2242 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 9/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.1970 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.1786 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 10/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.1547 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.1405 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 11/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.1207 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.1104 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 12/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.0945 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0875 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 13/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.0750 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0706 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 14/100
# 1094/1094 [==============================] - 4s 4ms/step - loss: 0.0606 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 15/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.0498 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0490 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 16/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.0418 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0421 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 17/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.0356 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0368 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 18/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.0307 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0327 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 19/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0268 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0294 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 20/100
# 1094/1094 [==============================] - 6s 6ms/step - loss: 0.0237 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0268 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 21/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.0212 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0247 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 22/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.0191 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0231 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 23/100
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.0175 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 24/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.0162 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0207 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 25/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.0151 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0198 - val_accuracy: 0.9982 - val_recall: 0.0000e+00
# Epoch 26/100
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.0142 - accuracy: 0.9995 - recall: 0.0000e+00 - val_loss: 0.0191 - val_accuracy: 0.9982 - val_recall: 0.0000e+00

# %% [markdown]
# # Performances

# %%
def predictions_results(X, y, model):
    preds = np.round(model.predict(X),0)

    # Measure recall and accuracy of the prediction
    score1 = recall_score(y, preds, pos_label=1)
    score2 = accuracy_score(y, preds)
    # Plotting the metrics, classification report and the confusion matrix

    print(f'Accuracy: {round(score2 * 100, 2)}')
    print(f'Recall: {round(score1 * 100, 2)}')

    cm = confusion_matrix(y, preds)
    disp = ConfusionMatrixDisplay(cm)
    print(classification_report(y, preds))
    disp.plot()
    plt.show()

# %% [markdown]
# ### Validation

# %%
predictions_results(X_val_def, y_val_lstm, model)
# Out:
# 160/160 [==============================] - 1s 2ms/step
# Accuracy: 99.82
# Recall: 0.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5108
#            1       0.00      0.00      0.00         9
#
#     accuracy                           1.00      5117
#    macro avg       0.50      0.50      0.50      5117
# weighted avg       1.00      1.00      1.00      5117
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Test

# %%
predictions_results(X_test_def, y_test_lstm, model)
# Out:
# 91/91 [==============================] - 0s 2ms/step
# Accuracy: 99.72
# Recall: 0.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2900
#            1       0.00      0.00      0.00         8
#
#     accuracy                           1.00      2908
#    macro avg       0.50      0.50      0.50      2908
# weighted avg       0.99      1.00      1.00      2908
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gltut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# The results are not the same of the model selected from the tuning. This is because the neural network is not that stable when it comes to imbalanced datasets. So the slightest difference in the weights can bring to a zero recall (especially in this case where we have only 8 cases of fog)

# %% [markdown]
# ### Metrics

# %%
history_dict = history.history

# Loss
rec = history_dict[metric[4:]]
val_rec = history_dict[metric]

# Loss
acc = history_dict[f'accuracy']
val_acc = history_dict[f'val_accuracy']

# Accuracy
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(val_loss) + 1) 

# Plotting accuracy
plt.figure(figsize = (15,10))
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'orange', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting recall
plt.figure(figsize = (15,10))
plt.plot(epochs, rec, 'b', label='Training recall')
plt.plot(epochs, val_rec, 'orange', label='Validation recall')
plt.title('Training and validation recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.show()


# Plotting loss
plt.figure(figsize = (15,10))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
